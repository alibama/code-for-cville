# %%
!pip list modules
# Out:
# Package                       Version
# ----------------------------- -----------
# aiobotocore                   1.2.2
# aiohttp                       3.7.4.post0
# aioitertools                  0.7.1
# alembic                       1.6.3
# altair                        4.1.0
# ansiwrap                      0.8.4
# anyio                         3.1.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# asn1crypto                    0.24.0
# astor                         0.8.1
# async-generator               1.10
# async-timeout                 3.0.1
# attrs                         21.2.0
# autopep8                      1.5.7
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# base58                        2.1.0
# bitarray                      1.2.2
# black                         21.5b1
# bleach                        3.3.0
# blinker                       1.4
# bokeh                         2.3.2
# bokeh-root-cmd                0.0.5
# boto3                         1.9.66
# botocore                      1.12.67
# Bottleneck                    1.3.2
# Brotli                        1.0.9
# cachetools                    4.2.2
# calysto-bash                  0.2.2
# cdsdashboards                 0.5.6
# certifi                       2020.12.5
# certipy                       0.1.3
# cffi                          1.12.3
# chardet                       4.0.0
# click                         7.1.2
# cloudpickle                   1.6.0
# colorama                      0.4.4
# conda                         4.10.1
# conda-package-handling        1.3.11
# configparser                  4.0.2
# cryptography                  3.3.2
# cycler                        0.10.0
# cytoolz                       0.11.0
# dash                          1.20.0
# dash-core-components          1.16.0
# dash-html-components          1.1.3
# dash-renderer                 1.9.1
# dash-table                    4.11.3
# dask                          2021.5.1
# decorator                     4.4.2
# defusedxml                    0.7.1
# distributed                   2021.5.1
# docutils                      0.17.1
# entrypoints                   0.3
# escapism                      1.0.1
# eth-abi                       2.1.1
# eth-account                   0.5.4
# eth-hash                      0.3.1
# eth-keyfile                   0.5.1
# eth-keys                      0.3.3
# eth-rlp                       0.2.1
# eth-typing                    2.2.2
# eth-utils                     1.10.0
# fasteners                     0.16
# feather-format                0.4.1
# Flask                         2.0.1
# Flask-Compress                1.9.0
# fsspec                        2021.5.0
# future                        0.18.2
# GDAL                          3.1.4
# gitdb                         4.0.7
# GitPython                     3.1.17
# graphviz                      0.16
# greenlet                      1.1.0
# HeapDict                      1.0.1
# hexbytes                      0.2.1
# htmlmin                       0.1.12
# humanize                      3.7.0
# idna                          2.10
# ImageHash                     4.2.0
# importlib-metadata            4.0.1
# importlib-resources           5.1.4
# ipdb                          0.13.9
# ipfshttpclient                0.7.0a1
# ipykernel                     5.5.5
# ipyparallel                   6.3.0
# ipython                       7.23.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# itsdangerous                  2.0.1
# jedi                          0.18.0
# jhsingle-native-proxy         0.7.6
# Jinja2                        3.0.1
# jmespath                      0.10.0
# joblib                        1.0.1
# json5                         0.9.5
# jsonschema                    3.2.0
# jupytab                       0.9.11
# jupytab-server                0.9.11
# jupyter-client                6.2.0
# jupyter-core                  4.7.1
# jupyter-kernel-gateway        2.5.0
# jupyter-resource-usage        0.5.1
# jupyter-server                1.8.0
# jupyter-server-mathjax        0.2.2
# jupyter-telemetry             0.1.0
# jupyter-videochat             0.5.1
# jupyterhub                    1.4.0
# jupyterlab                    3.0.16
# jupyterlab-drawio             0.9.0
# jupyterlab-git                0.30.1
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.5.2
# jupyterlab-sos                0.8.1
# jupyterlab-widgets            1.0.0
# jupytext                      1.11.2
# kiwisolver                    1.3.1
# libarchive-c                  2.8
# locket                        0.2.0
# lru-dict                      1.1.7
# Mako                          1.1.4
# Markdown                      3.3.4
# markdown-it-py                1.1.0
# MarkupSafe                    2.0.1
# matplotlib                    3.4.2
# matplotlib-inline             0.1.2
# mdit-py-plugins               0.2.8
# metakernel                    0.27.5
# missingno                     0.4.2
# mistune                       0.8.4
# modeler                       0.0.1
# monotonic                     1.5
# msgpack                       1.0.2
# multiaddr                     0.0.9
# multidict                     5.1.0
# multimethod                   1.4
# mypy-extensions               0.4.3
# nbclassic                     0.3.1
# nbclient                      0.5.3
# nbconvert                     6.0.7
# nbdime                        3.1.0
# nbformat                      5.1.3
# nbgitpuller                   0.9.0
# nest-asyncio                  1.5.1
# netaddr                       0.8.0
# networkx                      2.5.1
# notebook                      6.4.0
# nteract-on-jupyter            2.1.3
# numpy                         1.20.3
# oauthlib                      3.1.0
# oci                           2.38.4
# olefile                       0.46
# packaging                     20.9
# pamela                        1.0.0
# pandas                        1.2.4
# pandas-profiling              3.0.0
# pandocfilters                 1.4.3
# papermill                     2.3.3
# parsimonious                  0.8.1
# parso                         0.8.2
# partd                         1.2.0
# pathspec                      0.8.1
# pexpect                       4.8.0
# phik                          0.11.2
# pickleshare                   0.7.5
# Pillow                        8.2.0
# pip                           19.1.1
# ploomber                      0.11
# ploomber-scaffold             0.2.1
# plotly                        4.14.3
# plotlydash-tornado-cmd        0.0.6
# pluggy                        0.13.1
# portalocker                   1.7.0
# prometheus-client             0.10.1
# prompt-toolkit                3.0.18
# protobuf                      3.15.8
# psutil                        5.8.0
# ptyprocess                    0.7.0
# py                            1.10.0
# pyarrow                       4.0.0
# pycodestyle                   2.7.0
# pycosat                       0.6.3
# pycparser                     2.19
# pycryptodome                  3.10.1
# pydantic                      1.8.2
# pydeck                        0.6.2
# pydot                         1.4.2
# pydotplus                     2.0.2
# pyflakes                      2.3.1
# Pygments                      2.9.0
# pyOpenSSL                     19.0.0
# pyparsing                     2.4.7
# pyrsistent                    0.17.3
# PySocks                       1.7.0
# python-dateutil               2.8.1
# python-dotenv                 0.16.0
# python-editor                 1.0.4
# python-json-logger            2.0.1
# pytz                          2021.1
# PyWavelets                    1.1.1
# PyYAML                        5.1.2
# pyzmq                         22.1.0
# regex                         2021.4.4
# requests                      2.25.1
# retrying                      1.3.3
# rlp                           1.2.0
# rshiny-server-cmd             0.0.2
# ruamel-yaml                   0.15.46
# ruamel.yaml                   0.17.4
# ruamel.yaml.clib              0.2.2
# s3fs                          2021.5.0
# s3transfer                    0.1.13
# scipy                         1.6.3
# seaborn                       0.11.1
# Send2Trash                    1.5.0
# setuptools                    41.0.1
# simpervisor                   0.4
# six                           1.15.0
# smmap                         4.0.0
# sniffio                       1.2.0
# sortedcontainers              2.4.0
# sos                           0.22.4
# sos-bash                      0.20.0
# sos-notebook                  0.22.3
# sos-papermill                 0.2.1
# sos-pbs                       0.20.8
# sos-python                    0.18.4
# sos-r                         0.19.6
# SQLAlchemy                    1.4.15
# sqlparse                      0.4.1
# streamlit                     0.82.0
# streamlit-pandas-profiling    0.1.2
# streamlit-theme               0.58.0
# sweetviz                      2.1.0
# tabulate                      0.8.9
# tangled-up-in-unicode         0.1.0
# tblib                         1.7.0
# tenacity                      7.0.0
# terminado                     0.10.0
# testpath                      0.5.0
# textwrap3                     0.9.2
# toml                          0.10.2
# toolz                         0.11.1
# tornado                       6.1
# tqdm                          4.61.0
# traitlets                     5.0.5
# typed-ast                     1.4.3
# typing-extensions             3.7.4.3
# tzlocal                       2.1
# urllib3                       1.26.4
# validators                    0.18.2
# varint                        1.0.2
# visions                       0.7.1
# voila                         0.2.10
# voila-materialstream          0.4.0
# watchdog                      2.1.2
# wcwidth                       0.2.5
# web3                          5.18.0
# webencodings                  0.5.1
# websocket-client              1.0.1
# websockets                    8.1
# Werkzeug                      2.0.1
# wheel                         0.33.4
# widgetsnbextension            3.5.1
# windrose                      1.6.8
# wrapt                         1.12.1
# xxhash                        2.0.2
# yarl                          1.6.3
# zict                          2.0.0
# zipp                          3.4.1

# %%
import sqlalchemy as sa
from sqlalchemy import create_engine
#engine = create_engine("postgresql:///?User=postgres&Password=admin&Database=postgres&Server=127.0.0.1&Port=5432")
#engine = create_engine("postgresql:///?User=jupyter&;Password=code4cville&Database=expunge&Server=127.0.0.1&Port=5432")
import psycopg2 as db



try:
    conn = db.connect(host='localhost', database='expunge', user='jupyter', password='codeforcville', port='5432')
except:
    print("I am unable to connect to the database") 

cur = conn.cursor()
try:
    cur.execute("CREATE TABLE funky (id serial PRIMARY KEY, num integer, data varchar);")
except:
    print("I can't drop our test database!")

conn.commit() # <--- makes sure the change is shown in the database
conn.close()
cur.close()
